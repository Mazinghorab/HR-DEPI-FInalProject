# %% [markdown]
# ### Human Resources Dataset Analysis
#
# <center>
#   <img src="photos/01.jpeg">
# </center>

# %% [markdown]
# ### Data Model, Cleaning, and Preprocessing
#
# - Tools :
#     1. SQL
#     2. Python (Pandas, Matplotlib)
# - Expected :
#     1. Cleaning Dataset for **Analysis**
#     2. Making a **Data Preprocessing Notebook**
#
# <center>
#   <img src="photos/02.jpeg">
# </center>

# %% [markdown]
# ### Analysis Question Phase
#
# - Get ready of your **Analysis Questions** :
#     - We can define it as **Useful Insights**
#
# - Tools
#     1. SQL
#     2. Python (Pandas, Matplotlib)
#
# - Expected :
#     - Set of **Questions** that can be done via the Dataset
#     - Making the Answers **Plotted with the Given Tools**

# %% [markdown]
# ### Forcasting Question Phase
#
# - Determine some Forcasting Questions and Answer them Using **Visualization**.
#
# - Tools :
#     1. Python (Scikit-learn, Pandas, Matplotlib)
#
# - Expected :
#     - Make a **Good Visualization** with the Figured *Forcasting Questions*

# %% [markdown]
# ### Final Dashboard and Presentation
#
# - Building a Visualization Dashboard
#     - It can be Achieved Using **Tableau Visualization Dashboard**
#
# - Presentation
#     - Prepare a **Report and Presentation** Summarizing the *Project Work*
#     - Including **Data Analysis Model**, **Model Development**, **It's Deployment**
#
# - Tools :
#     1. SQL
#     2. Python (Pandas, Matplotlib)
#     3. Tableau
#
# - Expected
#     - Visualization of the **Dashboard**, **Final Report**, and **Presentation**
#
#
# <center>
#   <img src="photos/03.jpeg">
# </center>
